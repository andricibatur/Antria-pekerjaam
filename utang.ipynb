# %% [markdown]
# <a href="https://colab.research.google.com/github/andricibatur/Antria-pekerjaam/blob/main/utang.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content/debt_app

# Generate file folder android jika belum ada
# !flutter create .

# Atur minSdkVersion ke 24 (Android 7+)
# !sed -i 's/minSdkVersion .*/minSdkVersion 24/' android/app/build.gradle

# Ambil dependensi (csv & path_provider)
# !flutter pub get
# Out:
# /content/debt_app
# Recreating project ....
#   .idea/modules.xml (created)
#   .idea/workspace.xml (created)
#   .idea/libraries/KotlinJavaRuntime.xml (created)
#   .idea/libraries/Dart_SDK.xml (created)
#   .idea/runConfigurations/main_dart.xml (created)
#   README.md (created)
#   utang.iml (created)
#   windows/runner/main.cpp (created)
#   windows/runner/resource.h (created)
#   windows/runner/runner.exe.manifest (created)
#   windows/runner/CMakeLists.txt (created)
#   windows/runner/resources/app_icon.ico (created)
#   windows/runner/win32_window.cpp (created)
#   windows/runner/flutter_window.cpp (created)
#   windows/runner/utils.h (created)
#   windows/runner/win32_window.h (created)
#   windows/runner/flutter_window.h (created)
#   windows/runner/Runner.rc (created)
#   windows/runner/utils.cpp (created)
#   windows/.gitignore (created)
#   windows/flutter/CMakeLists.txt (created)
#   windows/CMakeLists.txt (created)
#   android/utang_android.iml (created)
# ...

# %%
# !flutter build apk --release
# Out:
#    567ms
#    358ms
#    384ms
#    311ms
#    319ms
#    296ms
# Checking the license for package NDK (Side by side) 28.2.13676358 in /content/android-sdk/licenses
# License for package NDK (Side by side) 28.2.13676358 accepted.
# Preparing "Install NDK (Side by side) 28.2.13676358 v.28.2.13676358".
# "Install NDK (Side by side) 28.2.13676358 v.28.2.13676358" ready.
# Installing NDK (Side by side) 28.2.13676358 in /content/android-sdk/ndk/28.2.13676358
# "Install NDK (Side by side) 28.2.13676358 v.28.2.13676358" complete.
# "Install NDK (Side by side) 28.2.13676358 v.28.2.13676358" finished.
# Checking the license for package Android SDK Build-Tools 35 in /content/android-sdk/licenses
# License for package Android SDK Build-Tools 35 accepted.
# Preparing "Install Android SDK Build-Tools 35 v.35.0.0".
# "Install Android SDK Build-Tools 35 v.35.0.0" ready.
# Installing Android SDK Build-Tools 35 in /content/android-sdk/build-tools/35.0.0
# ...
